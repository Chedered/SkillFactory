# %%
import numpy as np

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 12.35
s = 2.4
n = 64
z = 1.65

# %%
y = z*(s / math.sqrt(n))

# %%
print(round(x-y, 3),round(x+y, 3))
# Out:
# 11.855 12.845

# %%
from scipy.stats import norm
import math

def confidence_interval_norm(alpha, sigma, n, mean):
    value = -norm.ppf(alpha / 2) * sigma / math.sqrt(n)
    return round(mean - value, 2), round(mean + value, 2)

# %%
confidence_interval_norm(0.1,s,n,x)
# Out:
# (11.856543911914558, 12.843456088085441)

# %%
from scipy.stats import t

def confidence_interval_t(alpha, s, n, mean):
    value = -t.ppf(alpha / 2, n - 1) * s / math.sqrt(n)
    return round(mean - value, 2), round(mean + value, 2)

# %%
confidence_interval_t(0.1,s,n,x)
# Out:
# (11.84917933354761, 12.850820666452389)

# %%
x = 2000
s = 400
n = 15

# %%
confidence_interval_t(0.1,s,n,x)
# Out:
# (1818, 2182)

# %%
confidence_interval_t(0.05,s,n,x)
# Out:
# (1778, 2222)

# %%
confidence_interval_t(0.01,s,n,x)
# Out:
# (1693, 2307)

# %%
x = 3540
s = 1150
n = 250

# %%
confidence_interval_norm(0.01,s,n,x)
# Out:
# (3353, 3727)

# %%
array = np.array([1.2,0.2,1.6,1.9,-0.4,0.5,1.4,1.7,2.5,1.3])

# %%
x = array.mean()
s = array.std()
n = len(array)

# %%
confidence_interval_t(0.05,s,n,x)
# Out:
# (0.6, 1.78)
