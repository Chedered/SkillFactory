# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from scipy.optimize import minimize

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Содержание<a name="0"></a>

# %% [markdown]
# 1. [Что такое функция?](#1)
# 2. [Функция одной переменной](#2)
# 3. [Элементарные функции](#3)
# 4. [Производная. Общие понятия](#4)
# 5. [Производная. Монотонность. Дифференцирование](#5)
# 6. [Функция многих переменных](#6)
# 7. [Частные производные](#7)
# 8. [Градиент](#8)
# 9. [Матрица Гессе](#9)
# 10. [Умножение матриц](#10)
# 11. [Умножение на специальные матрицы](#11)
# 12. [Делители нуля](#12)
# 13. [Умножение и транспонирование матриц](#13)
# 14. [Практика. Умножение матриц](#14)
# 15. [Обратная матрица](#15)
# 16. [Определитель матрицы](#16)
# 17. [Линейная (не)зависимость](#17)
# 18. [Практика. Обратная матрица, ранг, определитель](#18)

# %% [markdown]
# ---

# %% [markdown]
# # Что такое функция?<a name="1"></a>

# %% [markdown]
# *Определение*: __Функцией__ в математике называется правило, по которому можно сопоставить элементы двух множеств.

# %% [markdown]
# *Формальное определение*: Для любого элемента *__х__* из множества *__Х__* существует единственный элемент *__y__* из множества *__Y__*, такой что __f(x) = y__:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Проиллюстрировав на картинке множество *__Х__* и множество *__Y__*, видим: у каждого элемента *__x__* из *__X__* должна быть пара *__y__* в *__Y__*. Таким образом, под действием функции *__f__* все множество *__X__* переходит в некоторую часть множества *__Y__*.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Восклицательный знак в формальном определении функции говорит о том, что такая пара *__x – y__* должна быть одна. Это значит, что нельзя одному *__х__* поставить в соответствие два разных *__y__*. И в то же время двум *__х__* — один *__y__*: сколько угодно!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Обозначения

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Числовые функции

# %% [markdown]
# * Функция одной переменной

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Функция многих переменных

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Вектор-функция

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Одна из важный идей анализа состоит в том, чтобы собрать небольшой пул хорошо изученных функций, из которых, как из кирпичей, можно построить любую другую функцию. Весь этот увлекательный конструктор называется __элементарными функциями__. Построить из таких кирпичей совсем любую функцию не получится, тем не менее элементарных функций довольно много и они закрывают большое количество прикладных задач.

# %% [markdown]
# Если мы хотим собирать сложные функции из простых, нам нужны __правила конструирования__:

# %% [markdown]
# 1. Сложение и вычитание

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Умножение и деление

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Композиция

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Композиция

# %% [markdown]
# Пусть у нас есть две функции — *__f__* и *__g, f__* действует из *__X__* в *__Y__*, а *__g__* — из *__Y__* в *__Z__*. Тогда мы можем сделать правило, по которому элементу из *__X__* будет ставиться в соответствие единственный элемент из *__Z__*. Это правило назовем *__h__* — оно и будет композицией правил *__g__* и *__f__*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Конструктор «Собери сам»

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Сумма и разность:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Произведение и частное:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Композиция:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Изменение величин в математике называют __приращением__. Например, изменение значения функции *__f(x)__* при изменении её аргумента будет приращением функции и запишется как *__Δf__*. Изменение аргумента будет приращением аргумента и запишется как *__Δx__*.

# %% [markdown]
# [К содержанию](#0)

# %% [markdown]
# ---

# %% [markdown]
# # Функция одной переменной<a name="2"></a>

# %% [markdown]
# *Определение*: __Числовая функция одной переменной__ —  это правило соответствия между числами *__x__* и *__y__*, согласно которому каждому *__x__* из области определения *__Df__* ставится в соответствие ровно один *__y__* из области значений *__Ef__*.

# %% [markdown]
# Обозначение:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Функции одной переменной часто изображают графически в декартовой системе координат

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Давайте рассмотрим на примере параболы, как можно построить график функции одной переменной в python. Как мы знаем, график параболы имеет вид  y = x2. Давайте построим её на промежутке [−10,10] с шагом изменения аргумента 0.01.

# %%
# х - аргумент в нашей функции. 
# передадим начало и конец числового отрезка нашей функции и шаг аргумента:
x = np.arange(-10, 10.01, 0.01) # массив значений аргумента

# построение графика параболы
plt.plot(x, x**2) 

# включим сетку на графике 
plt.grid(True)

# показать график
plt.show()

# %% [markdown]
# [К содержанию](#0)

# %% [markdown]
# ---

# %% [markdown]
# # Элементарные функции<a name="3"></a>

# %% [markdown]
# *Определение*:  __Элементарные функции__ — это функции, которые являются суммой, произведением или композицией элементов трех видов:

# %% [markdown]
# * Степенные функции

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Тригонометрические функции

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Показательные и логарифмические функции

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Элементарные функции можно записать понятной формулой из элементов–*кирпичиков*. А это значит, что их легко анализировать, зная свойства этих *кирпичиков*

# %% [markdown]
# ### Арктангенс

# %% [markdown]
# *Определение*:  В тригонометрии *__arctg (x)__* — это угол, тангенс которого равен *__х__*.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# То есть arctg (x) — функция обратная tg (x).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Свойства:

# %% [markdown]
# 1. Возрастает внутри «коридора» *__(–π/2, π/2)__*

# %% [markdown]
# 2. Вблизи нуля «похожа» на прямую *__y = x__*

# %% [markdown]
# 3.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Экспонента

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Идейные свойства:

# %% [markdown]
# 1. Возрастает от нуля до бесконечности

# %% [markdown]
# 2. Самая быстро растущая функция среди «кирпичей»

# %% [markdown]
# Технические свойства:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Экспоненциальное распределение и распределение Пуассона

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Сигмоида

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Свойства:

# %% [markdown]
# 1. Возрастает внутри «коридора» *__(0, 1)__*

# %% [markdown]
# 2. Вблизи нуля «похожа» на прямую *__y = αx + 0,5__*

# %% [markdown]
# 3.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Применение в ML:
# Функция активации нейрона

# %% [markdown]
# ### Натуральный логарифм

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Идейные свойства:

# %% [markdown]
# 1. Возрастает от 0 до +∞

# %% [markdown]
# 2. Самая медленно растущая функция среди «кирпичей»

# %% [markdown]
# Технические свойства:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Логарифм и экспонента являются взаимно обратными функциями:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Применение:

# %% [markdown]
# 1. Теория вероятностей: *логнормальное распределение*

# %% [markdown]
# 2. Статистика: *Maximum Likelihood*

# %% [markdown]
# ### Индикатор

# %% [markdown]
# Множества:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Правило:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Пример:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Применение:

# %% [markdown]
# 1. Теория вероятностей

# %% [markdown]
# 2. Функция активации нейрона:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# [К содержанию](#0)

# %% [markdown]
# ---

# %% [markdown]
# # Производная. Общие понятия<a name="4"></a>

# %% [markdown]
# Если функция достаточно «хорошая» рядом с известной нам точкой, то к ней можно привести касательную. И если не слишком далеко отойти от x0, то график функции будет очень близок к касательной.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Другими словами, в небольшой окрестности x0 наша функция будет почти прямой. Это значит, что её приращение можно считать как приращение линейной функции.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Синяя прямая — это __касательная__ к графику в точке *__A__*.
#
# * *__α__* — угол наклона касательной.
#
# * Точка *__A__* на графике имеет координаты *__(x0,f(x0))__* то есть *__(1,1).__*
#
# * Красной точкой обозначено настоящее значение нашей функции *__y1__* в точке *__x1__*.
#
# * Точка *__B__* на касательной — та точка, куда мы попали бы, если бы вышли из *__A__* не по графику, а по касательной.
#
# * *__b__* — линейное приращение.
#
# * Треугольник *__ABC__* прямоугольный, а значит *__b__* можно вычислить как *__Δx·tgα__*.
#
# * А значит, нужное нам значение *__y1__* приближённо равно *__y0+Δx⋅tgα__*.

# %% [markdown]
# Осталось понять, как вычислить *__tgα__*.

# %% [markdown]
# * Для этого давайте нарисуем хорду и обозначим за *__Δy__* настоящее приращении функции *__f__*.
# * С уменьшением *__Δx__* хорда будет все больше похожа на касательную, а её угол наклона — на угол *__α__*.
# * Если устремить *__Δx__* к нулю, то хорда превратится к касательную, а отношение *__Δy__* к *__Δx__* — в *__tgα__*.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *Определение*:  __Производная__ — есть предел приращений и тангенс угла наклона касательной.

# %% [markdown]
# ### Линеаризация

# %% [markdown]
# *Определение*: Задача о приближении, с помощью которой мы только что ввели понятие производной, называется __линеаризацией__.

# %% [markdown]
# У нас есть значение функции в точке *__x0__*. А хотим мы приближенно узнать ее значение в точке *__x1__*.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Мы показали, что если *__x1__* находится не очень далеко от *__x0__*, то отношение приращений примерно равно производной в точке *__x0__*.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Чем ближе новая точка расположена к старой, тем точнее приближение.

# %% [markdown]
# На идее линеаризации основываются *marginal effects* в нелинейных регрессиях.

# %% [markdown]
# ### Таблицей производных элементарных функций

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# [К содержанию](#0)

# %% [markdown]
# ---

# %% [markdown]
# # Производная. Монотонность. Дифференцирование<a name="5"></a>

# %% [markdown]
# Из линеаризации следует еще одна интерпретация производной. Сравним поведение трёх функций:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# __Выводы:__

# %% [markdown]
# 1. *__f′(x)>0⇒__* функция локально возрастает.

# %% [markdown]
# 2. Чем больше производная, тем быстрее растет функция.

# %% [markdown]
# 3. Нулевая производная означает отсутствие изменения функции.

# %% [markdown]
# Аналогичные выводы верны и для отрицательных производных, только функция в этом случае не растёт, а убывает.

# %% [markdown]
# Давайте на примере кубической параболы посмотрим, как работает определение промежутков возрастания и убывания функции с помощью производной:

# %% [markdown]
# ### Пример

# %% [markdown]
# Найдите промежутки возрастания и убывания функции *__f(x)=x3−12x__*

# %% [markdown]
# __Решение:__

# %% [markdown]
# *__f′(x)=3x2−12=3(x−2)(x+2)__*

# %% [markdown]
# Применим метод интервалов для определения знаков:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Функция *__f(x)__*
# возрастает при *__x∈(−∞,−2)∪(2,+∞)__*,
# убывает при *__x∈(−2,2)__*.

# %% [markdown]
# Нарисуем график функции *__f(x)__*:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Особый интерес представляют точки смены знака производной: *__2__* и *__−2__*:

# %% [markdown]
# * Слева от *__−2 f(x)__* возрастает, а справа убывает: значит, *__−2__* — __точка локального максимума__.

# %% [markdown]
# * Аналогично: *__2__* — __точка локального минимума.__

# %% [markdown]
# Это так называемые __локальные экстремумы__, и мы только что вывели *правило их поиска*:

# %% [markdown]
# 1. Находим все решения *__f′(x)=0__*

# %% [markdown]
# 2. Локальный максимум:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Локальный минимум:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Бывает, что производная обнуляется в какой-то точке, но не меняет знак, проходя через неё. То есть характер монотонности функции не меняется. Эта точка тоже будет стационарной, не являясь локальным экстремумом (максимумом или минимумом). Такие стационарные точки называют __точками перегиба__, так как в них функция меняет направление выпуклости.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# __Глобальный экстремум:__
# * На всей области определения
# * Или на его подмножестве

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Свойства:
# * Может не существовать
# * Если существует, то единственный

# %% [markdown]
# ### Правила дифференцирования

# %% [markdown]
# Давайте посмотрим, как связана производная с нашими правилами конструирования функций. Рассмотрим две функции:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Сумма и множитель:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Произведение и частное:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Композиция:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Как любой инструмент, производная имеет свои ограничения. У некоторых функций __производная не существует__.

# %% [markdown]
# 1. Такое происходит, если касательных бесконечно много, как например у функции *__y=|x|__* в нуле. Тем не менее у этой функции есть однозначная касательная, а значит, и производная слева от нуля и справа от нуля. Просто в нуле они не совпадают.

# %% [markdown]
# 2. Бывает также, что сама функция разрывна в точке *__x0__*.

# %% [markdown]
# 3. И наконец, бывает случай, когда касательная вертикальна, как, например, у функции *__y=√x__* в нуле.

# %% [markdown]
# Нет однозначной касательной

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Функция разрывна

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Вертикальная касательная

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# __Смысл производной:__

# %% [markdown]
# 1. Угол наклона касательной (его tg)

# %% [markdown]
# 2. Скорость изменения функции

# %% [markdown]
# __Как используется производная?__

# %% [markdown]
# 1. Приближенные вычисления

# %% [markdown]
# 2. Поиск локальных экстремумов

# %% [markdown]
# __Особые случаи:__

# %% [markdown]
# 1. Разрывная функция

# %% [markdown]
# 2. Разные производные слева и справа

# %% [markdown]
# 3. Вертикальная касательная

# %% [markdown]
# __Как считать?__

# %% [markdown]
# 1. Производные «кирпичиков»

# %% [markdown]
# 2. Правила дифференцирования

# %%
# х - аргумент в нашей функции. 
# передадим начало и конец числового отрезка нашей функции и шаг аргумента:
x = np.arange(-10, 10.01, 0.01) # массив значений аргумента

# построение графика параболы
plt.plot(x, -5*x**2+3*x+100) 

# включим сетку на графике 
plt.grid(True)

# показать график
plt.show()

# %% [markdown]
# [К содержанию](#0)

# %% [markdown]
# ---

# %% [markdown]
# # Функция многих переменных<a name="6"></a>

# %% [markdown]
# На практике часто нужно исследовать функцию нескольких (или многих) переменных. Такая функция получает на вход несколько чисел (аргументов), а возвращает одно значение

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Евклидово расстояние

# %% [markdown]
# Например, функция *__f(x,y)__* вычисляет корень из суммы квадратов *__x__* и *__y__*. Это ни что иное, как расстояние от точки *__(x,y)__* до начала координат или длина вектора *__r__* с координатами *__(x,y)__* .

# %% [markdown]
# Евклидово расстояние до начала координат:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Евклидово расстояние между точками:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Квадрат расстояния

# %% [markdown]
# Как вы помните, у квадратного корня есть проблемы с производной, поэтому для удобства в анализе часто пользуются квадратом расстояния:

# %% [markdown]
# * Квадрат расстояния до нуля:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Квадрат расстояния между точками:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Применение в ML:

# %% [markdown]
# 1. Минимизация вектора ошибок в регрессии

# %% [markdown]
# 2. Loss function в нейросетях и различных алгоритмах оптимизации

# %% [markdown]
# ### Loss function

# %% [markdown]
# Квадратичные потери или *__L2−loss__*:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Применение в ML:

# %% [markdown]
# 1. Регрессии

# %% [markdown]
# 2. Backpropagation

# %% [markdown]
# Бинарные потери или *__0.1−loss__*:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Применение в ML:

# %% [markdown]
# 1. Рекомендательные системы

# %% [markdown]
# 2. Отбор экспертов

# %% [markdown]
# ### Сигмоида

# %% [markdown]
# Одномерная:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Многомерная:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Применение в ML:

# %% [markdown]
# 1. Функция активации нейрона

# %% [markdown]
# [К содержанию](#0)

# %% [markdown]
# ---

# %% [markdown]
# # Частные производные<a name="7"></a>

# %% [markdown]
# Значение производной в точке равняется __тангенсу__ угла наклона касательной, проведённой в этой точке к графику функции. Но график функции многих переменных — это поверхность, у неё таких касательных — целая __касательная плоскость__. Получается, для каждого направления по касательной, а значит, и по своей __частной производной__.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Из всех направлений можно выбрать каноничные — параллельные координатным осям. Например, посмотрим, как меняется функция вдоль оси *__Ox__*. На рисунке это изменение изображено красной кривой.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Отношение приращения вдоль красной кривой к приращению *__x__* и есть значение частной производной по *__x__*:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Теперь из всей касательной плоскости можно найти прямую, соответствующую этой красной линии. Тангенс её наклона будет равен частной производной по *__x__*.

# %% [markdown]
# __Идея получения частной производной__ аналогична одномерному случаю. Пусть дана функция *__f(x1,x2,⋯,xn)__*, чтобы найти частную производную по переменной *__xi__*:

# %% [markdown]
# 1. Фиксируем все переменные кроме *__xi__*.

# %% [markdown]
# 2. Считаем приращение функции при изменении только этой переменной.

# %% [markdown]
# 3. Делим приращение из п. 2 на приращение нашей переменной.

# %% [markdown]
# 4. Уменьшаем *__Δxi__* и получаем *__∂f/∂xi__*

# %% [markdown]
# ### Пример

# %% [markdown]
# Найдите частные производные функции *__f(x,y)=x2+y2__*.

# %% [markdown]
# __Решение:__

# %% [markdown]
# Частная производная по *__x__*:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Частная производная по *__y__*:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Если же *__y__* является функцией от *__x__*, то переменные перестают быть независимым.

# %% [markdown]
# ### Пример

# %% [markdown]
# Найдите полную производную функции *__f(x,y)=x2+y2__* по *__x__*, если *__y=lnx__*.

# %% [markdown]
# __Решение:__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Интерпретация

# %% [markdown]
# Изменение функции вдоль координатных осей:

# %% [markdown]
# *__∂f/∂x1 > 0 ⇒ f(x1,⋯,xn)__* возрастает по *__x1__*

# %% [markdown]
# [К содержанию](#0)

# %% [markdown]
# ---

# %% [markdown]
# # Градиент<a name="8"></a>

# %% [markdown]
# Начнём знакомство с градиентом, обратившись к рисунку:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Стрелочку, задающую направление заливки назовём  «__градиент__».

# %% [markdown]
# * Линии, вдоль которых яркость одинаковая, будут ортогональны градиенту. Назовём их __линиями уровня яркости__.

# %% [markdown]
# * При перемещении по любой из линий яркость не меняется.

# %% [markdown]
# * Двигаясь вдоль градиента, мы максимально скоро выйдем на самое яркое место.

# %% [markdown]
# Если очень сильно упростить, именно так устроен __алгоритм градиентного спуска__.

# %% [markdown]
# Из такого простого примера мы узнали, что:

# %% [markdown]
# 1. Градиент показывает направление максимального изменения яркости

# %% [markdown]
# 2. Линии уровня яркости ортогональны градиенту

# %% [markdown]
# *Определение*: __Градиентом__ функции *__f__* называется вектор, состоящий из её частных производных по всем переменным

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Градиент указывает направление максимального роста функции. А его модуль — скорость этого роста.

# %% [markdown]
# ### Пример

# %% [markdown]
# Найдите градиент функции *__f(x,y)=x2+y2__* в точках *__M(0,0),N(1,−1),P(1,1)__*.

# %% [markdown]
# __Решение:__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# В точке *__N__* градиент *__(2,−2)__*, то есть при увеличении *__x__* функция *__f__* будет возрастать, а при увеличении *__y__* — убывать. В точке *__P__* значение градиента *__(2,2)__*, это значит что в окрестности *__P__* наша сумма квадратов возрастает по обеим переменным. В точке *__M__* градиент нулевой.

# %% [markdown]
# __Что значит нулевой вектор градиента?__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Смысл:

# %% [markdown]
# 1. Все частные производные равны нулю.

# %% [markdown]
# 2. Все касательные в точке *__M__* горизонтальны.

# %% [markdown]
# 3. *__M__* — стационарная точка функции *__f__*: максимум, минимум или седло (точка перегиба).

# %% [markdown]
# ### Линии уровня

# %% [markdown]
# *Определение*: В математике __линией уровня функции__ называется такая линия, вдоль которой значение функции постоянно.

# %% [markdown]
# На рисунке изображена поверхность, которая является графиком функции *__f(x,y)=x2+y2__*. Справа на плоскости изображены её линии уровня. Это концентрические круги с центром в нуле. У градиента есть важное свойство — __градиент ортогонален линиям уровня__. На рисунке справа вы видите стрелки, это векторы градиента функции.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# __Зачем нужен градиент?__

# %% [markdown]
# 1. Градиентный спуск в оптимизации

# %% [markdown]
# 2. Приближенные вычисления

# %% [markdown]
# [К содержанию](#0)

# %% [markdown]
# ---

# %% [markdown]
# # Матрица Гессе<a name="9"></a>

# %% [markdown]
# 1. Характер точек экстремума функции многих переменных

# %% [markdown]
# 2. Характер выпуклости функции многих переменных

# %% [markdown]
# *Определение*: __Матрица Гессе__ — это матрица вторых частных производных.

# %% [markdown]
# Пример матрицы Гессе для функции двух переменных:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Пример

# %% [markdown]
# Составьте матрицу Гессе для функции *__f(x)=x2+6x-2y2+4y__*

# %% [markdown]
# __Решение__

# %% [markdown]
# Шаг 1 - Найти частные производные

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Шаг 2 - Найти вторые частные производные (4 штуки)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Шаг 3 - Составить матрицу Гессе

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > Спектр матрицы Гессе определяет характер точек экстремумов функции и ее выпуклость.

# %% [markdown]
# [К содержанию](#0)

# %% [markdown]
# ---
